# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_html("/Users/cbitss/Aftab/Cbitss/demo.html")

# %%
data
# Out:
# [  Unnamed: 0  Sr No    Name  Age  Gender City
#  0          A      1   Aftab   21    Male  CHD
#  1          B      2    Aman   21    Male  CHD
#  2          C      3   Sahil   21    Male   UP
#  3          D      4  Satyam   19    Male  CHD
#  4          E      5  Sanket   21  Female  CHD]

# %%
# data.to_csv("")

# %%
df = pd.read_csv("/Users/cbitss/Aftab/Cbitss/4_PM/ML/student_performance.csv")

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  str
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), str(1)
# memory usage: 493.2 KB

# %%
df.corr(numeric_only = True)* 100
# Out:
#                                   Hours Studied  Previous Scores  Sleep Hours  \
# Hours Studied                        100.000000        -1.238992     0.124520
# Previous Scores                       -1.238992       100.000000     0.594422
# Sleep Hours                            0.124520         0.594422   100.000000
# Sample Question Papers Practiced       1.746317         0.788803     0.399022
# Performance Index                     37.373035        91.518914     4.810584
#
#                                   Sample Question Papers Practiced  \
# Hours Studied                                             1.746317
# Previous Scores                                           0.788803
# Sleep Hours                                               0.399022
# Sample Question Papers Practiced                        100.000000
# Performance Index                                         4.326833
#
#                                   Performance Index
# ...

# %%
df.replace(["Yes", "No"], [1, 0], inplace = True)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                          1            9
# 1                 4               82                          0            4
# 2                 8               51                          1            7
# 3                 5               52                          1            5
# 4                 7               75                          0            8
# ...             ...              ...                        ...          ...
# 9995              1               49                          1            4
# 9996              7               64                          1            8
# 9997              6               83                          1            8
# 9998              9               97                          1            7
# 9999              7               74                          0            8
#
# ...

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                          1            9
# 1                 4               82                          0            4
# 2                 8               51                          1            7
# 3                 5               52                          1            5
# 4                 7               75                          0            8
# ...             ...              ...                        ...          ...
# 9995              1               49                          1            4
# 9996              7               64                          1            8
# 9997              6               83                          1            8
# 9998              9               97                          1            7
# 9999              7               74                          0            8
#
# ...

# %%
# feature selection

# %%
df.corr()*100
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                        100.000000        -1.238992
# Previous Scores                       -1.238992       100.000000
# Extracurricular Activities             0.387254         0.836932
# Sleep Hours                            0.124520         0.594422
# Sample Question Papers Practiced       1.746317         0.788803
# Performance Index                     37.373035        91.518914
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.387254     0.124520
# Previous Scores                                     0.836932     0.594422
# Extracurricular Activities                        100.000000    -2.328364
# Sleep Hours                                        -2.328364   100.000000
# Sample Question Papers Practiced                    1.310278     0.399022
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(df.corr()*100, annot = True, fmt = "0.2F")
# Out:
# <Axes: >

# %%
# numerical columns relation scatter,   data behaviour
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                          1            9
# 1                 4               82                          0            4
# 2                 8               51                          1            7
# 3                 5               52                          1            5
# 4                 7               75                          0            8
# ...             ...              ...                        ...          ...
# 9995              1               49                          1            4
# 9996              7               64                          1            8
# 9997              6               83                          1            8
# 9998              9               97                          1            7
# 9999              7               74                          0            8
#
# ...

# %%
# SLR

# %%
plt.scatter(df["Hours Studied"][:20], df["Performance Index"][:20])

# %%
# SLR == Linear
plt.scatter(df["Previous Scores"][:50], df["Performance Index"][:50])

# %%
df = pd.read_csv("/Users/cbitss/Aftab/Cbitss/4_PM/ML/student_performance.csv")

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
for col in df.columns:
    # print(col)
    if df[col].dtype == "str":
        continue
    plt.scatter(df[col], df["Performance Index"])
    plt.title(f"Performance index vs {col}")
    plt.show()

# %%
for col in df.columns:
    # print(col)
    if df[col].dtype != "str":
        plt.scatter(df[col], df["Performance Index"])
        plt.title(f"Performance index vs {col}")
        plt.show()

# %%
# for col in df.columns:
#     # print(col)
#     plt.scatter( df["Performance Index"], df[col])
#     plt.title(f"Performance index vs {col}")
#     plt.show()

# %%
data = pd.read_csv("/Users/cbitss/Aftab/Cbitss/Churn_Modelling.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
for col in data.columns:
    if data[col].dtype == "str":
        continue
    print(col)
# Out:
# RowNumber
# CustomerId
# CreditScore
# Age
# Tenure
# Balance
# NumOfProducts
# HasCrCard
# IsActiveMember
# EstimatedSalary
# Exited

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender                 str
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object
